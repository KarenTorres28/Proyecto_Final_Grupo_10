# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
base = pd.read_csv('test.csv', encoding='utf8')

# %%
print(base.columns.tolist())
# Out:
# ['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
base.groupby('Pclass')['PassengerId'].count()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# Name: PassengerId, dtype: int64
