# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
base = pd.read_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', encoding='utf8')

# %%
def suma(x):
    s = 0
    for i in str(x):
        s += int(i)
    return s
base.apply(lambda x: suma(x.iat[0]), axis = 1)
# Out:
# 0     36
# 1     43
# 2     42
# 3     24
# 4     27
# 5     31
# 6     36
# 7     37
# 8     31
# 9     41
# 10    31
# 11    49
# 12    35
# 13    31
# 14    37
# 15    28
# 16    38
# 17    36
# dtype: int64

# %%
base["n"] =base.apply(lambda x: suma(x.iat[0]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
def comp(x,y):
    if x == y:
        return 5
    else:
        return 1

# %%
def costo(n,x):
    resto = 2*x + 23
    valorc = n*x**2
    resul = resto + valorc
    return resul
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 1"] = base.apply(lambda x: (costo(x.iat[4],105)-costo(x.iat[4],100))/5 , axis = 1 ) #Convierte toso los datos a numeros, primero convierte todo a str temporalmente, despues reemplaza comas por puntos y convierte lo corregido a numerico
base["calificación"] = base.apply(lambda x: comp(x.iat[1],x.iat[5]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
nombre_archivo_salida = 'Ejercicio_calificado.csv' 
base.to_csv(nombre_archivo_salida, index=False)
