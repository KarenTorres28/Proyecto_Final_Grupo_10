# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
base = pd.read_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', encoding='utf8')

# %%
def suma(x):
    s = 0
    x_str = str(x)
    x_limpia = x_str.replace('.', '')
    for i in x_limpia:
        if i.isdigit():
            s += int(i)
    return s
base.apply(lambda x: suma(x.iat[0]), axis = 1)
# Out:
# 0     36
# 1     43
# 2     42
# 3     24
# 4     27
# 5     31
# 6     36
# 7     37
# 8     31
# 9     41
# 10    31
# 11    49
# 12    35
# 13    31
# 14    37
# 15    28
# 16    38
# 17    36
# dtype: int64

# %%
base["n"] =base.apply(lambda x: suma(x.iat[0]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
def comp(x,y):
    if x == y:
        return 5
    else:
        return 1

# %%
def costo(n,x):
    resto = 2*x + 23
    valorc = n*x**2
    resul = resto + valorc
    return resul
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 1"] = base.apply(lambda x: (costo(x.iat[4],105)-costo(x.iat[4],100))/5 , axis = 1 ) #Convierte toso los datos a numeros, primero convierte todo a str temporalmente, despues reemplaza comas por puntos y convierte lo corregido a numerico
base["CP1"] = base.apply(lambda x: comp(x.iat[1],x.iat[5]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
col = base.pop('CP1')
base.insert(6, 'CP1', col)

# %%
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
nombre_original = 'Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv'
base.to_csv(nombre_original, index=False)

# %%
from funciones import *

# %%
print(base.columns.tolist())
# Out:
# ['Número de documento', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 105 unidades (Poner dos decimales)', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 101 unidades (Poner dos decimales)\n', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)', 'n', 'Punto 1', 'CP1', 'Punto 2', 'CP2', 'Punto 3', 'CP3', 'NF ', 'calificación 3']

# %%
promedio(base, 'CP1')
# Out:
# np.float64(3.888888888888889)

# %%
base.describe()
# Out:
#        Número de documento  \
# count         1.800000e+01
# mean          1.069793e+09
# std           5.864996e+07
# min           1.000795e+09
# 25%           1.020124e+09
# 50%           1.052857e+09
# 75%           1.111079e+09
# max           1.193232e+09
#
#        Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# count                                          18.000000
# mean                                        27672.793889
# std                                         90429.310520
# min                                             6.360000
# 25%                                          5894.150000
# 50%                                          7279.500000
# 75%                                          8202.000000
# max                                        389866.330000
#
# ...

# %%
from funciones import *

# %%
import os
import matplotlib.pyplot as plt

p_CP1 = promedio(base, "CP1")
p_CP2 = promedio(base, "CP2")
p_CP3 = promedio(base, "CP3")
p_NF  = promedio(base, "NF ")

# Crear figura
plt.figure()
plt.bar(["CP1", "CP2", "CP3", "NF "], [p_CP1, p_CP2, p_CP3, p_NF])
plt.title("Promedios")
plt.xlabel("Columnas")
plt.ylabel("Promedio")

# Guardar figura en la carpeta que está un nivel arriba
plt.savefig("../figuras/promedios.png", dpi=300, bbox_inches='tight')

# Mostrar (opcional)
plt.show()

# Cerrar figura
plt.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.savefig("figuras/Promedios.png")  # Se guarda como PNG
#       2 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# ...

# %%
nombre_imagen = os.path.join("figuras", nombre_original.replace(".csv", ".png"))

# %%
if not os.path.exists("figuras"):
    os.makedirs("figuras")

plt.savefig(nombre_imagen)
plt.show()

print(f"Gráfico guardado como: {nombre_imagen}")

# %%
plt.savefig(nombre_imagen)
plt.show()

print(f"Gráfico guardado como: {nombre_imagen}")
# Out:
# Gráfico guardado como: figuras/Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).png
