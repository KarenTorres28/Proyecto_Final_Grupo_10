# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
base = pd.read_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', encoding='utf8')

# %%
def suma(x):
    s = 0
    x_str = str(x)
    x_limpia = x_str.replace('.', '')
    for i in x_limpia:
        if i.isdigit():
            s += int(i)
    return s
base.apply(lambda x: suma(x.iat[0]), axis = 1)
# Out:
# 0     36
# 1     43
# 2     42
# 3     24
# 4     27
# 5     31
# 6     36
# 7     37
# 8     31
# 9     41
# 10    31
# 11    49
# 12    35
# 13    31
# 14    37
# 15    28
# 16    38
# 17    36
# dtype: int64

# %%
base["n"] =base.apply(lambda x: suma(x.iat[0]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.0
# 1                                             8602.0
# 2                                             8402.0
# 3                                             4802.0
# 4                                             5402.0
#
#     n  Punto 1  CP1  Punto 2  calificación 2  Punto 3  calificación 3  \
# 0  36   7382.0    5   7238.0               5   7202.0               5
# 1  43   8817.0    5   8645.0               5   8602.0               5
# 2  42   8612.0    5   8444.0               5   8402.0               5
# 3  24   4922.0    5   4826.0               5   4802.0               5
# 4  27   5537.0    5   5429.0               5   5402.0               5
#
#    Calificicación final
# 0                    5.0
# 1                    5.0
# 2                    5.0
# 3                    5.0
# 4                    5.0

# %%
def comp(x,y):
    if x == y:
        return 5
    else:
        return 1

# %%
def costo(n,x):
    resto = 2*x + 23
    valorc = n*x**2
    resul = resto + valorc
    return resul
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 2"] = base.apply(lambda x: (costo(x.iat[4],101)-costo(x.iat[4],100))/1 , axis = 1 )
base["CP2"] = base.apply(lambda x: comp(x.iat[2],x.iat[7]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.0
# 1                                             8602.0
# 2                                             8402.0
# 3                                             4802.0
# 4                                             5402.0
#
#     n  Punto 1  CP1  Punto 2  calificación 2  Punto 3  calificación 3  \
# 0  36   7382.0    5   7238.0               5   7202.0               5
# 1  43   8817.0    5   8645.0               5   8602.0               5
# 2  42   8612.0    5   8444.0               5   8402.0               5
# 3  24   4922.0    5   4826.0               5   4802.0               5
# 4  27   5537.0    5   5429.0               5   5402.0               5
#
#    Calificicación final   CP2
# 0                    5.0    5
# 1                    5.0    5
# 2                    5.0    5
# 3                    5.0    5
# 4                    5.0    5

# %%
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 3"] = base.apply(lambda x: (2 * x.iat[4] * 100)+2,  axis=1).round(2)
base["CP3"] = base["calificación 3"] = base.apply(lambda x: comp(x.iat[3],x.iat[9]), axis = 1) 
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.0
# 1                                             8602.0
# 2                                             8402.0
# 3                                             4802.0
# 4                                             5402.0
#
#     n  Punto 1  CP1  Punto 2  calificación 2  Punto 3  calificación 3  \
# 0  36   7382.0    5   7238.0               5   7202.0               5
# 1  43   8817.0    5   8645.0               5   8602.0               5
# 2  42   8612.0    5   8444.0               5   8402.0               5
# 3  24   4922.0    5   4826.0               5   4802.0               5
# 4  27   5537.0    5   5429.0               5   5402.0               5
#
#    Calificicación final   CP2  CP3
# 0                    5.0    5    5
# 1                    5.0    5    5
# 2                    5.0    5    5
# 3                    5.0    5    5
# 4                    5.0    5    5

# %%
def calificacion_final(c1,c2,c3):
    s = c1+c2+c3
    res = s/3
    return res

# %%
base["NF "] = base.apply(lambda x :calificacion_final(x.iat[6],x.iat[8],x.iat[10]), axis = 1)
base
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.00
# 1                                             8817.00
# 2                                             8612.00
# 3                                             4922.00
# 4                                             5537.00
# 5                                             6357.00
# 6                                             7382.00
# 7                                           389866.33
# 8                                             6356.60
# 9                                             8407.00
# 10                                               6.36
# 11                                           10047.00
# 12                                            7177.00
# 13                                            6357.00
# 14                                            7587.00
# 15                                            5740.00
# 16                                             175.00
# 17                                            7382.00
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.00
# 1                                             8645.00
# 2                                             8444.00
# 3                                             4826.00
# 4                                             5429.00
# 5                                             6233.00
# 6                                             7238.00
# 7                                             3739.23
# 8                                             6233.00
# 9                                             8243.00
# 10                                               6.23
# 11                                            9851.00
# 12                                            7037.00
# 13                                            6233.00
# 14                                            7439.00
# 15                                            5620.00
# 16                                             152.00
# 17                                            7238.00
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.00
# 1                                             8602.00
# 2                                             8402.00
# 3                                             4802.00
# 4                                             5402.00
# 5                                             6202.00
# 6                                                2.00
# 7                                             7402.00
# 8                                               62.00
# 9                                             8202.00
# 10                                               6.20
# 11                                               2.00
# 12                                            7002.00
# 13                                            6202.00
# 14                                              76.00
# 15                                            5600.00
# 16                                               1.00
# 17                                             366.82
#
#      n  Punto 1  CP1  Punto 2  CP2  Punto 3  CP3       NF
# 0   36   7382.0    5   7238.0    5   7202.0    5  5.000000
# 1   43   8817.0    5   8645.0    5   8602.0    5  5.000000
# 2   42   8612.0    5   8444.0    5   8402.0    5  5.000000
# 3   24   4922.0    5   4826.0    5   4802.0    5  5.000000
# 4   27   5537.0    5   5429.0    5   5402.0    5  5.000000
# 5   31   6357.0    5   6233.0    5   6202.0    5  5.000000
# 6   36   7382.0    5   7238.0    5   7202.0    1  3.666667
# 7   37   7587.0    1   7439.0    1   7402.0    5  2.333333
# 8   31   6357.0    1   6233.0    5   6202.0    1  2.333333
# 9   41   8407.0    5   8243.0    5   8202.0    5  5.000000
# 10  31   6357.0    1   6233.0    1   6202.0    1  1.000000
# 11  49  10047.0    5   9851.0    5   9802.0    1  3.666667
# 12  35   7177.0    5   7037.0    5   7002.0    5  5.000000
# 13  31   6357.0    5   6233.0    5   6202.0    5  5.000000
# 14  37   7587.0    5   7439.0    5   7402.0    1  3.666667
# 15  28   5742.0    1   5630.0    1   5602.0    1  1.000000
# 16  38   7792.0    1   7640.0    1   7602.0    1  1.000000
# 17  36   7382.0    5   7238.0    5   7202.0    1  3.666667

# %%
print(base.columns.tolist())
# Out:
# ['Número de documento', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 105 unidades (Poner dos decimales)', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 101 unidades (Poner dos decimales)\n', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)', 'n', 'Punto 1', 'CP1', 'Punto 2', 'Punto 3', 'Calificicación final ', 'CP2', 'CP3', 'NF ']

# %%
col = base.pop('CP2')
base.insert(8, 'CP2', col)

# %%
col = base.pop('CP3')
base.insert(10, 'CP3', col)

# %%
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.0
# 1                                             8602.0
# 2                                             8402.0
# 3                                             4802.0
# 4                                             5402.0
#
#     n  Punto 1  CP1  Punto 2  CP2  Punto 3  CP3  NF
# 0  36   7382.0    5   7238.0    5   7202.0    5  5.0
# 1  43   8817.0    5   8645.0    5   8602.0    5  5.0
# 2  42   8612.0    5   8444.0    5   8402.0    5  5.0
# 3  24   4922.0    5   4826.0    5   4802.0    5  5.0
# 4  27   5537.0    5   5429.0    5   5402.0    5  5.0

# %%
nombre_original = 'Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv'
base.to_csv(nombre_original, index=False)
