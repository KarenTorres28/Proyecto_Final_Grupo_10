# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
base = pd.read_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', encoding='utf8')

# %%
def suma(x):
    s = 0
    x_str = str(x)
    x_limpia = x_str.replace('.', '')
    for i in x_limpia:
        if i.isdigit():
            s += int(i)
    return s
base.apply(lambda x: suma(x.iat[0]), axis = 1)
# Out:
# 0     36
# 1     43
# 2     42
# 3     24
# 4     27
# 5     31
# 6     36
# 7     37
# 8     31
# 9     41
# 10    31
# 11    49
# 12    35
# 13    31
# 14    37
# 15    28
# 16    38
# 17    36
# dtype: int64

# %%
base["n"] =base.apply(lambda x: suma(x.iat[0]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
def comp(x,y):
    if x == y:
        return 5
    else:
        return 1

# %%
def costo(n,x):
    resto = 2*x + 23
    valorc = n*x**2
    resul = resto + valorc
    return resul
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 2"] = base.apply(lambda x: (costo(x.iat[4],101)-costo(x.iat[4],100))/1 , axis = 1 )
base["CP2"] = base.apply(lambda x: comp(x.iat[2],x.iat[7]), axis = 1)
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
base.iloc[:, 1:] = base.iloc[:, 1:].astype(str).replace(',', '.', regex=True).apply(pd.to_numeric, errors='coerce').round(2)
base["Punto 3"] = base.apply(lambda x: (2 * x.iat[4] * 100)+2,  axis=1).round(2)
base["CP3"]  = base.apply(lambda x: comp(x.iat[3],x.iat[9]), axis = 1) 
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
def calificacion_final(c1,c2,c3):
    s = c1+c2+c3
    res = s/3
    return res

# %%
base["NF "] = base.apply(lambda x :calificacion_final(x.iat[6],x.iat[8],x.iat[10]), axis = 1)
base
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.00
# 1                                             8817.00
# 2                                             8612.00
# 3                                             4922.00
# 4                                             5537.00
# 5                                             6357.00
# ...

# %%
print(base.columns.tolist())
# Out:
# ['Número de documento', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 105 unidades (Poner dos decimales)', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nHallar el costo promedio de producir\xa0 de 100 a 101 unidades (Poner dos decimales)\n', 'Sea la función de costo C(x) = n*x^2 + 2*x + 23.\xa0\nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)', 'n', 'Punto 1', 'CP1', 'Punto 2', 'CP2', 'Punto 3', 'CP3', 'NF ', 'calificación 3']

# %%
col = base.pop('CP2')
base.insert(8, 'CP2', col)

# %%
col = base.pop('CP3')
base.insert(10, 'CP3', col)

# %%
base.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
# ...

# %%
from funciones import *

# %%
desviacion(base, 'CP1')
# Out:
# np.float64(1.8435543958499072)

# %%
base.describe()
# Out:
#        Número de documento  \
# count         1.800000e+01
# mean          1.069793e+09
# std           5.864996e+07
# min           1.000795e+09
# 25%           1.020124e+09
# 50%           1.052857e+09
# 75%           1.111079e+09
# max           1.193232e+09
#
#        Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# count                                          18.000000
# mean                                        27672.793889
# std                                         90429.310520
# min                                             6.360000
# 25%                                          5894.150000
# 50%                                          7279.500000
# 75%                                          8202.000000
# max                                        389866.330000
#
# ...

# %%
from funciones import percentiles

# %%
percentiles(base, 'CP1')
# Out:
# (np.float64(2.0), np.float64(5.0), np.float64(5.0))

# %%
nombre_original = 'Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv'
base.to_csv(nombre_original, index=False)

# %%
from funciones import *

# %%
import matplotlib.pyplot as plt

p_CP1 = desviacion(base, "CP1")
p_CP2 = desviacion(base, "CP2")
p_CP3 = desviacion(base, "CP3")
p_NF  = desviacion(base, "NF ")

# --- Crear figura ---
fig, ax = plt.subplots()

ax.bar(["CP1", "CP2", "CP3", "NF "], [p_CP1, p_CP2, p_CP3, p_NF])
ax.set_title("Desviaciones")
ax.set_xlabel("Columnas")
ax.set_ylabel("Desviacion")

# --- Guardar ---
fig.savefig("../figuras/Desviaciones.png", dpi=300, bbox_inches='tight')

# --- Mostrar ---
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Obtener percentiles 10,20,...90 de NF ---
valores = [np.percentile(base["NF "], p) for p in range(10, 100, 10)]
etiquetas = [f"{p}%" for p in range(10, 100, 10)]

# --- Crear figura ---
fig, ax = plt.subplots()

ax.bar(etiquetas, valores)
ax.set_title("Percentiles de NF")
ax.set_xlabel("Percentiles")
ax.set_ylabel("Valor")

# --- Guardar ---
fig.savefig("../figuras/Percentiles.png", dpi=300, bbox_inches='tight')

# --- Mostrar ---
plt.show()
